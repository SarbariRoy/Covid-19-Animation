# %%
import pandas as pd
import matplotlib.animation as animation
# https://blog.exxactcorp.com/fighting-coronavirus-covid-19-with-data-science-crowdsourcing-3-projects-you-should-know-about/
    
# https://www.kaggle.com/imdevskp/covid-19-analysis-visualization-comparisons/data

#https://www.kaggle.com/imdevskp/corona-virus-report

# country wise plot of confirmed cases, deaths,
# percentage of male female
# death rate
# blood group distribution of confirmed cases

# %%
dt = pd.read_csv("/Users/z0045sy/Documents/Python Hacks/Barchart Race/covid_19_clean_complete.csv",parse_dates=['Date'])

# %%
dt
# Out:
#       Province/State  Country/Region      Lat      Long       Date  Confirmed  \
# 0                NaN        Thailand  15.0000  101.0000 2020-01-22          2
# 1                NaN           Japan  36.0000  138.0000 2020-01-22          2
# 2                NaN       Singapore   1.2833  103.8333 2020-01-22          0
# 3                NaN           Nepal  28.1667   84.2500 2020-01-22          0
# 4                NaN        Malaysia   2.5000  112.5000 2020-01-22          0
# ...              ...             ...      ...       ...        ...        ...
# 15442          Aruba     Netherlands  12.5186  -70.0358 2020-03-18          4
# 15443            NaN          Zambia -15.4167   28.2833 2020-03-18          2
# 15444            NaN        Djibouti  11.8251   42.5903 2020-03-18          1
# 15445            NaN     Gambia, The  13.4432  -15.3101 2020-03-18          1
# 15446     Montserrat  United Kingdom  16.7425  -62.1874 2020-03-18          1
#
#        Deaths  Recovered
# ...

# %%
# Libraries
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
 
# Set the dimension of the figure
my_dpi=96
plt.figure(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
 
# read the data (on the web)
# data = pd.read_csv('http://python-graph-gallery.com/wp-content/uploads/TweetSurfData.csv', sep=";")
data = dt
 
# Make the background map
m=Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.3)
m.drawcoastlines(linewidth=0.1, color="white")
 
# prepare a color for each point depending on the continent.
data['labels_enc'] = pd.factorize(data['Country/Region'])[0]
 
# Add a point per position
m.scatter(data['Long'], data['Lat'], s=data['Confirmed']/6, alpha=0.4, c=data['Deaths'], cmap="Set1")
 
# copyright and source data info
plt.text( -170, -58,'Where people talk about #Surf\n\nData collected on twitter by @R_Graph_Gallery during 300 days\nPlot realized with Python and the Basemap library', ha='left', va='bottom', size=9, color='#555555' )
 
# Save as png
# plt.savefig('#315_Tweet_Surf_Bubble_map1.png', bbox_inches='tight')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app

# %%
import numpy
from matplotlib.pylab import *
from mpl_toolkits.axes_grid1 import host_subplot
import matplotlib.animation as animation
import pandas as pd
import random 
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML
import datetime
from matplotlib.ticker import MaxNLocator
# f0 = figure(num = 0, figsize = (12, 8))

# %%
my_dpi=100
f0,ax= plt.subplots(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
# f0,ax  =plt.subplots()
m=Basemap(ax=ax, llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.3)
m.drawcoastlines(linewidth=0.1, color="white")


#     print(data)
# prepare a color for each point depending on the continent.
data['labels_enc'] = pd.factorize(data['Country/Region'])[0]
# print(data['labels_enc'])
# Add a point per position
ax.scatter(data['Long'], data['Lat'], s=data['Confirmed']/6, alpha=0.4, c=data['Deaths'], cmap="Set1")

# copyright and source data info
plt.text( -170, -58,'Where people talk about #Surf\n\nData collected on twitter by @R_Graph_Gallery during 300 days\nPlot realized with Python and the Basemap library', ha='left', va='bottom', size=9, color='#555555' )

plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   after removing the cwd from sys.path.

# %%
def updateData(current_date):
    ax.clear()
    date =current_date
    m=Basemap(ax=ax, llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
#     m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
    m.fillcontinents(color='grey', alpha=0.3)
    m.drawcoastlines(linewidth=0.1, color="white")

    data = dt[dt['Date'] == date]
    print(date)
    # prepare a color for each point depending on the continent.
    data['labels_enc'] = pd.factorize(data['Country/Region'])[0]
#     print(data['labels_enc'])
    # Add a point per position
    ax.scatter(data['Long'], data['Lat'], s=data['Confirmed']/6, alpha=0.4, c=data['Deaths'], cmap="Set1")
    ax.text(1, 0.8, date, transform=ax.transAxes, color='red', size=30, ha='right', weight=800)
    # copyright and source data info
    plt.text( -170, -58,'Where people talk about #Surf\n\nData collected on twitter by @R_Graph_Gallery during 300 days\nPlot realized with Python and the Basemap library', ha='left', va='bottom', size=9, color='#555555' )
    
    
    
    #####
    country = np.random.choice(df[df['Date'] <= current_date]['Country/Region'])
    df_ax1= df[(df['Date'] <= date) & (df['Country/Region']==country)]
    ax1.clear()
#     ax1.set_ylim([0,maxm])
    ax1.plot(df_ax1['Date'],df_ax1['Confirmed'])
#     print(df['Confirmed'].max())
    ax1.get_xaxis().set_ticks([])
    ax1.yaxis.set_ticks_position('right')
    ax1.text(1, 0.9, country, transform=ax1.transAxes, color='black', size=12, ha='right', weight=800)
    ax1.text(1, 0.8, date, transform=ax1.transAxes, color='red', size=12, ha='right', weight=800)

# %%
matplotlib.use('Qt5Agg')
f0= figure(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
# f0= figure(figsize=(12,8), dpi=my_dpi)
f0.suptitle("Corona Virus Confirmed cases till date", fontsize=24)

ax = subplot2grid((3, 5), (0, 0), colspan=4, rowspan=2)
ax1 = subplot2grid((3, 5), (0, 4), colspan=1, rowspan=3)


#######
dt['check'] = dt['Country/Region'] +"#"+dt['Date'].apply(lambda x: str(x))
# df[ (df['Country/Region']=="Singapore")]
# df.info()



df = dt[['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
       'Deaths', 'Recovered', 'labels_enc']]

df['check'] = df['Country/Region'] +"#"+df['Date'].apply(lambda x: str(x))
maxm = df['Confirmed'].max()

# df = df.groupby(['Country/Region', 'Date'])['Confirmed'].agg('sum').reset_index().sort_values(['Date'])
df = df.groupby(['Country/Region', 'Date']).agg({'Confirmed': "sum",'Deaths': "sum",'Recovered':"sum"}).reset_index().sort_values(['Date'])

df=df[df['Confirmed'] > 20]
df['check'] = df['Country/Region'] +"#"+df['Date'].apply(lambda x: str(x))
maxm = df['Confirmed'].max()




ranges = sorted(set(dt['Date'].tolist()), key=dt['Date'].tolist().index)
# ranges = dt['check'].unique().tolist()
simulation = animation.FuncAnimation(f0, updateData, blit=False, frames=ranges, interval=1, repeat=False)

# Uncomment the next line if you want to save the animation
# simulation.save(filename='sim.mp4',fps=30,dpi=300)

plt.show()
# HTML(simulation.to_jshtml())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
current = df['Date'].tolist()[40]
df[['Date'] <= current]
#                  ['Country/Region'])

# %%
df

# %%
np.random.choice(df['Country/Region'])
# Out:
# 'Malaysia'

# %%
#country wise confirmed cases
# data = dt[dt['Date'] == current_date]

# %%
df = dt[['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
       'Deaths', 'Recovered', 'labels_enc']]
df = df.groupby(['Country/Region', 'Date'])['Confirmed'].agg('sum').reset_index().sort_values(['date'])
# df[ (df['Country/Region']=="Singapore")]
# df.info()

d['check'] = df['Country/Region'] +"#"+df['Date'].apply(lambda x: str(x))
maxm = df['Confirmed'].max()

df = dt[['Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
       'Deaths', 'Recovered', 'labels_enc']]
df = df.groupby(['Country/Region', 'Date'])['Confirmed'].agg('sum').reset_index().sort_values(['Date'])

df=df[df['Confirmed'] > 50]
df['check'] = df['Country/Region'] +"#"+df['Date'].apply(lambda x: str(x))
maxm = df['Confirmed'].max()

# %%
df=df[df['Confirmed'] > 50]
df['check'] = df['Country/Region'] +"#"+df['Date'].apply(lambda x: str(x))
maxm = df['Confirmed'].max()

# %%
#line plot
def updateData(current_date):
    country = current_date.split('#')[0]
    date = current_date.split('#')[1]
#     print(country)
    df_ax1= df[(df['Date'] <= date) & (df['Country/Region']==country)]
    ax1.clear()
    ax1.set_ylim([0,maxm])
    ax1.plot(df_ax1['Date'],df_ax1['Confirmed'])
#     print(df['Confirmed'].max())
    ax1.get_xaxis().set_ticks([])
    ax1.text(1, 0.9, country, transform=ax.transAxes, color='black', size=12, ha='right', weight=800)
    ax1.text(1, 0.8, date, transform=ax.transAxes, color='red', size=12, ha='right', weight=800)

# %%
matplotlib.use('Qt5Agg')
f0,ax1= plt.subplots(figsize=(2600/my_dpi, 1800/my_dpi), dpi=my_dpi)
# ax1.set_ylim(0,df['Confirmed'].max())
# ranges = list(set(df['check'].tolist()), key=df['check'].tolist().index)
ranges = df['check'].unique().tolist()
simulation = animation.FuncAnimation(f0, updateData, blit=False, frames=ranges, interval=400, repeat=False)

# Uncomment the next line if you want to save the animation
# simulation.save(filename='sim.mp4',fps=30,dpi=300)

plt.show()
# HTML(simulation.to_jshtml())

# %%
df[df['Country/Region'] != 'China']['Confirmed'].max()

# %% [raw]
# df_ax1= df[df['Date'] <= current_date]
# ax1.plot(df_ax1['Date'],df_ax1['Confirmed'])

# %%
df[ (df['Country/Region']=="Singapore")]

# %%
if(df['Deaths'] == 0 , 0 , str(round(df['Deaths'].sum()/df['Confirmed'].sum(),2)))

# %%
x = 0 if df['Deaths'].max() == 0 else str(round(df['Deaths'].sum()/df['Confirmed'].sum(),2))

# %%
x

# %%
df.iloc[-1]['Deaths']

# %%
df.iloc[-1,:]['Deaths']

# %%
df_ax1= df[(df['Date'] <= df['Date'].tolist()[40]) & (df['Country/Region']=="India")]

# %%
df['Date'].tolist()[40]
